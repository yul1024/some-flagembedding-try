# %%
from FlagEmbedding import BGEM3FlagModel

# %%
model = BGEM3FlagModel(
    model_name_or_path=r"D:\model\BAAI\bge-m3",
    use_fp16=True,
)

# %%
result = model.encode(
    sentences='haha',
    batch_size=32,
    max_length=8192,
    return_dense=True,
    return_sparse=True,
    return_colbert_vecs=True,
)
# Out:
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
result
# Out:
# {'dense_vecs': array([-0.01217765,  0.00533882, -0.01892849, ...,  0.01121462,
#         -0.04523227,  0.05996431], dtype=float32),
#  'lexical_weights': defaultdict(int, {'22010': 0.34668848}),
#  'colbert_vecs': array([[ 0.03358928,  0.00885195, -0.02423928, ...,  0.02940811,
#          -0.01181546, -0.0445538 ],
#         [ 0.0412381 ,  0.00503687, -0.04525701, ...,  0.02392904,
#           0.04594899, -0.00922914]], dtype=float32)}
